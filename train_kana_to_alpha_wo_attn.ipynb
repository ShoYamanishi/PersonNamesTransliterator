# %% [markdown]
# # Training Script
# Direction: Kana to Alpha
#
# Encoder: GRU
#
# Decoder: GRU
#
# Hyper Parameter: *NUM_UNITS*

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time
import datetime

import json

from functools import total_ordering

from RedBlackTree.rbtree import RedBlackNode
from RedBlackTree.rbtree import RedBlackTree
from StackDecoder.stack_decoder import StackDecoderPath
from StackDecoder.stack_decoder import StackDecoder

# %% [markdown]
# ## Parameter Definitions

# %%
TOKENIZER_ALPHAS                 = 'training_data/alphas_tokenizer.json'
TOKENIZER_KANAS                  = 'training_data/kanas_tokenizer.json'

TRANING_DATA_FILE_90_10_10       = "training_data/alpha_to_kana_train.txt"
VALIDATION_DATA_FILE_90_10_10    = "training_data/alpha_to_kana_validation.txt"

EPOCHS                           = 1000
BATCH_SIZE                       =   64
NUM_UNITS                        =  512 # <= Hyper Parameter

VALIDATION_BEAM_WIDTH            =    5
VALIDATION_NBEST                 =    5
VALIDATION_MAX_LEN_KANAS_CUTOFF  =   12
VALIDATION_MAX_LEN_ALPHAS_CUTOFF =   16

CHECKPOINT_DIR                   = f'training_output/kana_to_alpha_{str(NUM_UNITS)}_wo_attn'

# %% [markdown]
# ## Arrange Tokeniers and Training & Validation Sets

# %%
# Load tokenizers
with open(TOKENIZER_ALPHAS) as f:
    data = json.load(f)
    alphas_tokenizer = tf.keras.preprocessing.text.tokenizer_from_json(data)

with open(TOKENIZER_KANAS) as f:
    data = json.load(f)
    kanas_tokenizer = tf.keras.preprocessing.text.tokenizer_from_json(data)
    
EMB_DIM_ALPHAS = len( alphas_tokenizer.word_index ) + 1
EMB_DIM_KANAS  = len( kanas_tokenizer.word_index  ) + 1

# %%
# Load training data and validation data

train_kanas = []
train_alphas = []
with open( TRANING_DATA_FILE_90_10_10, "r", encoding="utf-8" ) as fp_train:
    for line in fp_train:
        alpha, kana = line.strip().split('\t')
        train_kanas.append(kana)
        train_alphas.append(alpha)

valid_kanas = []
valid_alphas = []
with open( VALIDATION_DATA_FILE_90_10_10, "r", encoding="utf-8" ) as fp_valid:
    for line in fp_valid:
        alpha, kana = line.strip().split( '\t' )
        valid_alphas.append( '<' + alpha + '>' )
        valid_kanas.append( '<' + kana + '>' )

validation_pairs = list(zip(valid_alphas, valid_kanas))


# Interleave with spaces so that we can utilize Kera's tokenizer.

train_kanas_spaced = []
for kana_str in train_kanas:
    kana_list = []
    kana_list[:0] = kana_str
    train_kanas_spaced.append( "< " + ' '.join(kana_list) + " >" ) 

train_alphas_spaced = []
for alpha_str in train_alphas:
    alpha_list = []
    alpha_list[:0] = alpha_str
    train_alphas_spaced.append( "< " + ' '.join(alpha_list) + " >" ) 

train_alphas_tensor = alphas_tokenizer.texts_to_sequences(train_alphas_spaced)
train_alphas_tensor = tf.keras.preprocessing.sequence.pad_sequences(train_alphas_tensor, padding='post')

train_kanas_tensor  = kanas_tokenizer.texts_to_sequences(train_kanas_spaced)
train_kanas_tensor  = tf.keras.preprocessing.sequence.pad_sequences(train_kanas_tensor, padding='post')

max_length_alphas, max_length_kanas = train_alphas_tensor.shape[1], train_kanas_tensor.shape[1]

# %%
BUFFER_SIZE = len(train_alphas_tensor)
steps_per_epoch = len(train_alphas_tensor)//BATCH_SIZE

dataset = tf.data.Dataset.from_tensor_slices((train_alphas_tensor, train_kanas_tensor)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# ## Create Encoder and Decoder

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, state):
    x = self.embedding(x)
    x, state = self.gru(x, initial_state = state)
    return x, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(EMB_DIM_KANAS, EMB_DIM_KANAS, NUM_UNITS, BATCH_SIZE)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)   

  def call(self, x, state):
    x = self.embedding(x)
    x, state = self.gru(x, state)
    x = self.fc(x)
    return x, state

# %%
decoder = Decoder(EMB_DIM_ALPHAS, EMB_DIM_ALPHAS, NUM_UNITS, BATCH_SIZE)

# %% [markdown]
# ## Check the Shapes of the Encoder and the Decoder

# %%
for alpha, kana in dataset.take(steps_per_epoch):
    encoder_state = encoder.initialize_hidden_state()
    encoder_out, encoder_state2 = encoder(kana, encoder_state)
    decoder_state = encoder_state
    decoder_pred, decoder_state2 = decoder(alpha, decoder_state)
    break
kana.shape, alpha.shape, encoder_state.shape, encoder_out.shape, encoder_state2.shape, decoder_pred.shape, decoder_state2.shape
# Out:
# (TensorShape([64, 14]),
#  TensorShape([64, 18]),
#  TensorShape([64, 512]),
#  TensorShape([64, 14, 512]),
#  TensorShape([64, 512]),
#  TensorShape([64, 30]),
#  TensorShape([64, 512]))

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## One Training Step with Forward and Backprop with Incremental Teacher Forcing

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([alphas_tokenizer.word_index['<']] * BATCH_SIZE, 1)
    
    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
       # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)
    
      loss += loss_function(targ[:, t], predictions)
    
      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

    # dec_input = tf.expand_dims(targ, 1)
    # dec_output, dec_hidden = decoder(dec_input, dec_hidden)
    
    
  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %% [markdown]
# ## Checkpoint to Save the Models

# %%
# File outputs (checkpoints and metrics for tensorboard)

checkpoint_prefix = os.path.join(CHECKPOINT_DIR, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = os.path.join( CHECKPOINT_DIR, current_time, 'train' )
validation_log_dir = os.path.join( CHECKPOINT_DIR, current_time, 'validation' )
train_summary_writer = tf.summary.create_file_writer( train_log_dir )
validation_summary_writer = tf.summary.create_file_writer( validation_log_dir )

# %% [markdown]
# ## Validation using Validation Set by Nbest Stack Decoder
# The score is calculated by edit distance in Nbest against target.

# %%
# Validation

# Following levenshtein() is taken from 
# https://en.wikibooks.org/wiki/Algorithm_Implementation/Strings/Levenshtein_distance#Python
# under  Creative Commons Attribution-ShareAlike License.
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]



def validate(sentence_pairs):

    BOS = alphas_tokenizer.word_index['<']
    EOS = alphas_tokenizer.word_index['>']

    stack_decoder = StackDecoder(decoder, BOS, EOS, use_attn = False)

    avg_edit_dist = 0.0
    index = 0
    for alphas, kanas in sentence_pairs:
        if (index % 10 == 0):
            print('validating {}/{}'.format(index, len(sentence_pairs)))
        index += 1
        inputs = [kanas_tokenizer.word_index[i] for i in kanas]
        inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_kanas,
                                                         padding='post')
        inputs = tf.convert_to_tensor(inputs)

        hidden = [tf.zeros((1, NUM_UNITS))]
        enc_out, enc_hidden = encoder(inputs, hidden)

        dec_hidden = enc_hidden
        dec_input = tf.expand_dims([alphas_tokenizer.word_index['<']], 0)

        nbest_raw = stack_decoder.NBest( enc_out, enc_hidden, VALIDATION_BEAM_WIDTH, VALIDATION_NBEST, VALIDATION_MAX_LEN_KANAS_CUTOFF + 2 ) 
    
        min_edit_dist = -1
        for r in nbest_raw:
            candidate = ""
            for i in r.sentence:
                candidate += alphas_tokenizer.index_word[i] 
            edit_dist = levenshtein(alphas, candidate)
            if min_edit_dist == -1 or edit_dist < min_edit_dist:
                min_edit_dist = edit_dist
        avg_edit_dist += min_edit_dist
    return avg_edit_dist / len(sentence_pairs)

# %% [markdown]
# ## Training Execution

# %%
#checkpoint.restore('./CHECKPOINT_DIR/ckpt-1')

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (alpha, kana)) in enumerate(dataset.take(steps_per_epoch)):

    batch_loss = train_step(kana, alpha, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every epoch
  checkpoint.save(file_prefix = checkpoint_prefix)

  accuracy = validate(list(validation_pairs)[0:100])
    
  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Validation Accuracy {:0.4f}'.format(accuracy))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

  with train_summary_writer.as_default():
    tf.summary.scalar('loss', total_loss / steps_per_epoch, step=epoch)
    tf.summary.scalar('accuracy', accuracy, step=epoch)
# Out:
# Epoch 1 Batch 0 Loss 1.6001
# Epoch 1 Batch 100 Loss 1.2233
# Epoch 1 Batch 200 Loss 1.1262
# Epoch 1 Batch 300 Loss 1.1279
# Epoch 1 Batch 400 Loss 1.0528
# Epoch 1 Batch 500 Loss 1.0156
# Epoch 1 Batch 600 Loss 0.9018
# Epoch 1 Batch 700 Loss 0.8792
# Epoch 1 Batch 800 Loss 0.9761
# Epoch 1 Batch 900 Loss 0.9210
# Epoch 1 Batch 1000 Loss 0.8522
# Epoch 1 Batch 1100 Loss 0.8102
# Epoch 1 Batch 1200 Loss 0.8005
# Epoch 1 Batch 1300 Loss 0.7405
# Epoch 1 Batch 1400 Loss 0.7707
# Epoch 1 Batch 1500 Loss 0.6882
# Epoch 1 Batch 1600 Loss 0.6948
# Epoch 1 Batch 1700 Loss 0.6951
# Epoch 1 Batch 1800 Loss 0.6463
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 1 Loss 0.9104
# Validation Accuracy 3.4600
# Time taken for 1 epoch 444.9984362125397 sec
#
# Epoch 2 Batch 0 Loss 0.6072
# Epoch 2 Batch 100 Loss 0.6019
# Epoch 2 Batch 200 Loss 0.5967
# Epoch 2 Batch 300 Loss 0.5779
# Epoch 2 Batch 400 Loss 0.5398
# Epoch 2 Batch 500 Loss 0.5812
# Epoch 2 Batch 600 Loss 0.5387
# Epoch 2 Batch 700 Loss 0.4984
# Epoch 2 Batch 800 Loss 0.4643
# Epoch 2 Batch 900 Loss 0.5098
# Epoch 2 Batch 1000 Loss 0.4411
# Epoch 2 Batch 1100 Loss 0.4520
# Epoch 2 Batch 1200 Loss 0.3964
# Epoch 2 Batch 1300 Loss 0.4542
# Epoch 2 Batch 1400 Loss 0.3618
# Epoch 2 Batch 1500 Loss 0.3055
# Epoch 2 Batch 1600 Loss 0.3728
# Epoch 2 Batch 1700 Loss 0.3622
# Epoch 2 Batch 1800 Loss 0.3427
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 2 Loss 0.4806
# Validation Accuracy 1.5000
# Time taken for 1 epoch 438.3993799686432 sec
#
# Epoch 3 Batch 0 Loss 0.3439
# Epoch 3 Batch 100 Loss 0.3508
# Epoch 3 Batch 200 Loss 0.3716
# Epoch 3 Batch 300 Loss 0.3505
# Epoch 3 Batch 400 Loss 0.3525
# Epoch 3 Batch 500 Loss 0.3615
# Epoch 3 Batch 600 Loss 0.3508
# Epoch 3 Batch 700 Loss 0.3202
# Epoch 3 Batch 800 Loss 0.3498
# Epoch 3 Batch 900 Loss 0.3767
# Epoch 3 Batch 1000 Loss 0.2864
# Epoch 3 Batch 1100 Loss 0.3288
# Epoch 3 Batch 1200 Loss 0.3007
# Epoch 3 Batch 1300 Loss 0.3155
# Epoch 3 Batch 1400 Loss 0.3287
# Epoch 3 Batch 1500 Loss 0.3593
# Epoch 3 Batch 1600 Loss 0.3374
# Epoch 3 Batch 1700 Loss 0.3289
# Epoch 3 Batch 1800 Loss 0.2944
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 3 Loss 0.3263
# Validation Accuracy 1.2900
# Time taken for 1 epoch 444.4100558757782 sec
#
# Epoch 4 Batch 0 Loss 0.3449
# Epoch 4 Batch 100 Loss 0.2684
# Epoch 4 Batch 200 Loss 0.2858
# Epoch 4 Batch 300 Loss 0.2740
# Epoch 4 Batch 400 Loss 0.2781
# Epoch 4 Batch 500 Loss 0.2645
# Epoch 4 Batch 600 Loss 0.2820
# Epoch 4 Batch 700 Loss 0.2845
# Epoch 4 Batch 800 Loss 0.2956
# Epoch 4 Batch 900 Loss 0.2514
# Epoch 4 Batch 1000 Loss 0.2580
# Epoch 4 Batch 1100 Loss 0.2616
# Epoch 4 Batch 1200 Loss 0.2645
# Epoch 4 Batch 1300 Loss 0.2412
# Epoch 4 Batch 1400 Loss 0.2584
# Epoch 4 Batch 1500 Loss 0.2271
# Epoch 4 Batch 1600 Loss 0.3104
# Epoch 4 Batch 1700 Loss 0.2454
# Epoch 4 Batch 1800 Loss 0.3038
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 4 Loss 0.2731
# Validation Accuracy 1.1200
# Time taken for 1 epoch 438.62687158584595 sec
#
# Epoch 5 Batch 0 Loss 0.2347
# Epoch 5 Batch 100 Loss 0.2544
# Epoch 5 Batch 200 Loss 0.2658
# Epoch 5 Batch 300 Loss 0.2295
# Epoch 5 Batch 400 Loss 0.2575
# Epoch 5 Batch 500 Loss 0.2132
# Epoch 5 Batch 600 Loss 0.2879
# Epoch 5 Batch 700 Loss 0.2429
# Epoch 5 Batch 800 Loss 0.2355
# Epoch 5 Batch 900 Loss 0.2500
# Epoch 5 Batch 1000 Loss 0.2183
# Epoch 5 Batch 1100 Loss 0.2530
# Epoch 5 Batch 1200 Loss 0.2365
# Epoch 5 Batch 1300 Loss 0.2183
# Epoch 5 Batch 1400 Loss 0.2205
# Epoch 5 Batch 1500 Loss 0.2379
# Epoch 5 Batch 1600 Loss 0.2209
# Epoch 5 Batch 1700 Loss 0.2104
# Epoch 5 Batch 1800 Loss 0.2448
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 5 Loss 0.2396
# Validation Accuracy 1.0200
# Time taken for 1 epoch 437.2237982749939 sec
#
# Epoch 6 Batch 0 Loss 0.2200
# Epoch 6 Batch 100 Loss 0.1904
# Epoch 6 Batch 200 Loss 0.1866
# Epoch 6 Batch 300 Loss 0.2244
# Epoch 6 Batch 400 Loss 0.2085
# Epoch 6 Batch 500 Loss 0.2213
# Epoch 6 Batch 600 Loss 0.1977
# Epoch 6 Batch 700 Loss 0.2040
# Epoch 6 Batch 800 Loss 0.1997
# Epoch 6 Batch 900 Loss 0.1973
# Epoch 6 Batch 1000 Loss 0.2424
# Epoch 6 Batch 1100 Loss 0.2050
# Epoch 6 Batch 1200 Loss 0.2484
# Epoch 6 Batch 1300 Loss 0.2368
# Epoch 6 Batch 1400 Loss 0.2203
# Epoch 6 Batch 1500 Loss 0.1656
# Epoch 6 Batch 1600 Loss 0.1766
# Epoch 6 Batch 1700 Loss 0.1790
# Epoch 6 Batch 1800 Loss 0.2209
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 6 Loss 0.2137
# Validation Accuracy 0.9400
# Time taken for 1 epoch 442.42123675346375 sec
#
# Epoch 7 Batch 0 Loss 0.1834
# Epoch 7 Batch 100 Loss 0.1574
# Epoch 7 Batch 200 Loss 0.1924
# Epoch 7 Batch 300 Loss 0.1468
# Epoch 7 Batch 400 Loss 0.1574
# Epoch 7 Batch 500 Loss 0.1968
# Epoch 7 Batch 600 Loss 0.1640
# Epoch 7 Batch 700 Loss 0.2167
# Epoch 7 Batch 800 Loss 0.2054
# Epoch 7 Batch 900 Loss 0.1855
# Epoch 7 Batch 1000 Loss 0.2282
# Epoch 7 Batch 1100 Loss 0.1913
# Epoch 7 Batch 1200 Loss 0.1942
# Epoch 7 Batch 1300 Loss 0.1986
# Epoch 7 Batch 1400 Loss 0.2071
# Epoch 7 Batch 1500 Loss 0.1721
# Epoch 7 Batch 1600 Loss 0.1881
# Epoch 7 Batch 1700 Loss 0.2415
# Epoch 7 Batch 1800 Loss 0.1831
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 7 Loss 0.1914
# Validation Accuracy 0.9100
# Time taken for 1 epoch 431.5487847328186 sec
#
# Epoch 8 Batch 0 Loss 0.1588
# Epoch 8 Batch 100 Loss 0.1541
# Epoch 8 Batch 200 Loss 0.1543
# Epoch 8 Batch 300 Loss 0.1817
# Epoch 8 Batch 400 Loss 0.1590
# Epoch 8 Batch 500 Loss 0.1475
# Epoch 8 Batch 600 Loss 0.1741
# Epoch 8 Batch 700 Loss 0.1796
# Epoch 8 Batch 800 Loss 0.1501
# Epoch 8 Batch 900 Loss 0.1378
# Epoch 8 Batch 1000 Loss 0.1823
# Epoch 8 Batch 1100 Loss 0.1836
# Epoch 8 Batch 1200 Loss 0.1596
# Epoch 8 Batch 1300 Loss 0.2023
# Epoch 8 Batch 1400 Loss 0.1839
# Epoch 8 Batch 1500 Loss 0.1952
# Epoch 8 Batch 1600 Loss 0.1791
# Epoch 8 Batch 1700 Loss 0.1928
# Epoch 8 Batch 1800 Loss 0.1781
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 8 Loss 0.1722
# Validation Accuracy 1.0000
# Time taken for 1 epoch 427.14222836494446 sec
#
# Epoch 9 Batch 0 Loss 0.1539
# Epoch 9 Batch 100 Loss 0.1369
# Epoch 9 Batch 200 Loss 0.1306
# Epoch 9 Batch 300 Loss 0.1388
# Epoch 9 Batch 400 Loss 0.1383
# Epoch 9 Batch 500 Loss 0.1418
# Epoch 9 Batch 600 Loss 0.1709
# Epoch 9 Batch 700 Loss 0.1493
# Epoch 9 Batch 800 Loss 0.1725
# Epoch 9 Batch 900 Loss 0.1827
# Epoch 9 Batch 1000 Loss 0.1598
# Epoch 9 Batch 1100 Loss 0.1681
# Epoch 9 Batch 1200 Loss 0.1640
# Epoch 9 Batch 1300 Loss 0.1734
# Epoch 9 Batch 1400 Loss 0.1418
# Epoch 9 Batch 1500 Loss 0.1618
# Epoch 9 Batch 1600 Loss 0.1675
# Epoch 9 Batch 1700 Loss 0.1719
# Epoch 9 Batch 1800 Loss 0.1698
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 9 Loss 0.1553
# Validation Accuracy 0.9300
# Time taken for 1 epoch 428.37484788894653 sec
#
# Epoch 10 Batch 0 Loss 0.1441
# Epoch 10 Batch 100 Loss 0.1226
# Epoch 10 Batch 200 Loss 0.1129
# Epoch 10 Batch 300 Loss 0.1411
# Epoch 10 Batch 400 Loss 0.1099
# Epoch 10 Batch 500 Loss 0.1266
# Epoch 10 Batch 600 Loss 0.1459
# Epoch 10 Batch 700 Loss 0.1762
# Epoch 10 Batch 800 Loss 0.1402
# Epoch 10 Batch 900 Loss 0.1528
# Epoch 10 Batch 1000 Loss 0.1453
# Epoch 10 Batch 1100 Loss 0.1502
# Epoch 10 Batch 1200 Loss 0.1049
# Epoch 10 Batch 1300 Loss 0.1531
# Epoch 10 Batch 1400 Loss 0.1710
# Epoch 10 Batch 1500 Loss 0.1226
# Epoch 10 Batch 1600 Loss 0.1647
# Epoch 10 Batch 1700 Loss 0.1587
# Epoch 10 Batch 1800 Loss 0.1293
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 10 Loss 0.1401
# Validation Accuracy 1.0100
# Time taken for 1 epoch 427.99034905433655 sec
#
# Epoch 11 Batch 0 Loss 0.1034
# Epoch 11 Batch 100 Loss 0.1219
# Epoch 11 Batch 200 Loss 0.1009
# Epoch 11 Batch 300 Loss 0.1040
# Epoch 11 Batch 400 Loss 0.1214
# Epoch 11 Batch 500 Loss 0.1017
# Epoch 11 Batch 600 Loss 0.1725
# Epoch 11 Batch 700 Loss 0.1308
# Epoch 11 Batch 800 Loss 0.1130
# Epoch 11 Batch 900 Loss 0.1108
# Epoch 11 Batch 1000 Loss 0.1324
# Epoch 11 Batch 1100 Loss 0.1347
# Epoch 11 Batch 1200 Loss 0.1453
# Epoch 11 Batch 1300 Loss 0.1715
# Epoch 11 Batch 1400 Loss 0.1304
# Epoch 11 Batch 1500 Loss 0.1057
# Epoch 11 Batch 1600 Loss 0.1584
# Epoch 11 Batch 1700 Loss 0.1262
# Epoch 11 Batch 1800 Loss 0.1411
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 11 Loss 0.1279
# Validation Accuracy 0.9600
# Time taken for 1 epoch 427.21334886550903 sec
#
# Epoch 12 Batch 0 Loss 0.1481
# Epoch 12 Batch 100 Loss 0.0749
# Epoch 12 Batch 200 Loss 0.0964
# Epoch 12 Batch 300 Loss 0.1060
# Epoch 12 Batch 400 Loss 0.1025
# Epoch 12 Batch 500 Loss 0.1004
# Epoch 12 Batch 600 Loss 0.0903
# Epoch 12 Batch 700 Loss 0.1074
# Epoch 12 Batch 800 Loss 0.0960
# Epoch 12 Batch 900 Loss 0.1073
# Epoch 12 Batch 1000 Loss 0.0983
# Epoch 12 Batch 1100 Loss 0.1405
# Epoch 12 Batch 1200 Loss 0.1830
# Epoch 12 Batch 1300 Loss 0.0998
# Epoch 12 Batch 1400 Loss 0.0998
# Epoch 12 Batch 1500 Loss 0.1456
# Epoch 12 Batch 1600 Loss 0.1293
# Epoch 12 Batch 1700 Loss 0.1017
# Epoch 12 Batch 1800 Loss 0.1328
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 12 Loss 0.1168
# Validation Accuracy 0.9500
# Time taken for 1 epoch 431.54194688796997 sec
#
# Epoch 13 Batch 0 Loss 0.1092
# Epoch 13 Batch 100 Loss 0.0935
# Epoch 13 Batch 200 Loss 0.0698
# Epoch 13 Batch 300 Loss 0.1227
# Epoch 13 Batch 400 Loss 0.1163
# Epoch 13 Batch 500 Loss 0.0747
# Epoch 13 Batch 600 Loss 0.1181
# Epoch 13 Batch 700 Loss 0.1171
# Epoch 13 Batch 800 Loss 0.0854
# Epoch 13 Batch 900 Loss 0.0986
# Epoch 13 Batch 1000 Loss 0.1099
# Epoch 13 Batch 1100 Loss 0.1033
# Epoch 13 Batch 1200 Loss 0.1153
# Epoch 13 Batch 1300 Loss 0.1149
# Epoch 13 Batch 1400 Loss 0.1286
# Epoch 13 Batch 1500 Loss 0.1250
# Epoch 13 Batch 1600 Loss 0.1426
# Epoch 13 Batch 1700 Loss 0.0877
# Epoch 13 Batch 1800 Loss 0.1019
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 13 Loss 0.1077
# Validation Accuracy 1.0300
# Time taken for 1 epoch 431.11425709724426 sec
#
# Epoch 14 Batch 0 Loss 0.0795
# Epoch 14 Batch 100 Loss 0.1229
# Epoch 14 Batch 200 Loss 0.0726
# Epoch 14 Batch 300 Loss 0.0878
# Epoch 14 Batch 400 Loss 0.0828
# Epoch 14 Batch 500 Loss 0.0789
# Epoch 14 Batch 600 Loss 0.1023
# Epoch 14 Batch 700 Loss 0.0904
# Epoch 14 Batch 800 Loss 0.0800
# Epoch 14 Batch 900 Loss 0.1074
# Epoch 14 Batch 1000 Loss 0.0907
# Epoch 14 Batch 1100 Loss 0.1061
# Epoch 14 Batch 1200 Loss 0.1045
# Epoch 14 Batch 1300 Loss 0.1199
# Epoch 14 Batch 1400 Loss 0.1008
# Epoch 14 Batch 1500 Loss 0.0979
# Epoch 14 Batch 1600 Loss 0.1046
# Epoch 14 Batch 1700 Loss 0.1081
# Epoch 14 Batch 1800 Loss 0.1144
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 14 Loss 0.1002
# Validation Accuracy 1.0300
# Time taken for 1 epoch 439.59300541877747 sec
#
# Epoch 15 Batch 0 Loss 0.0776
# Epoch 15 Batch 100 Loss 0.0719
# Epoch 15 Batch 200 Loss 0.0967
# Epoch 15 Batch 300 Loss 0.0692
# Epoch 15 Batch 400 Loss 0.0774
# Epoch 15 Batch 500 Loss 0.0862
# Epoch 15 Batch 600 Loss 0.0934
# Epoch 15 Batch 700 Loss 0.0897
# Epoch 15 Batch 800 Loss 0.0704
# Epoch 15 Batch 900 Loss 0.0871
# Epoch 15 Batch 1000 Loss 0.1313
# Epoch 15 Batch 1100 Loss 0.1136
# Epoch 15 Batch 1200 Loss 0.0813
# Epoch 15 Batch 1300 Loss 0.1012
# Epoch 15 Batch 1400 Loss 0.1050
# Epoch 15 Batch 1500 Loss 0.1192
# Epoch 15 Batch 1600 Loss 0.1011
# Epoch 15 Batch 1700 Loss 0.1116
# Epoch 15 Batch 1800 Loss 0.1177
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 15 Loss 0.0942
# Validation Accuracy 1.0400
# Time taken for 1 epoch 431.07654786109924 sec
#
# Epoch 16 Batch 0 Loss 0.0849
# Epoch 16 Batch 100 Loss 0.0696
# Epoch 16 Batch 200 Loss 0.0798
# Epoch 16 Batch 300 Loss 0.0749
# Epoch 16 Batch 400 Loss 0.0869
# Epoch 16 Batch 500 Loss 0.0748
# Epoch 16 Batch 600 Loss 0.0654
# Epoch 16 Batch 700 Loss 0.0671
# Epoch 16 Batch 800 Loss 0.0853
# Epoch 16 Batch 900 Loss 0.0915
# Epoch 16 Batch 1000 Loss 0.1026
# Epoch 16 Batch 1100 Loss 0.1076
# Epoch 16 Batch 1200 Loss 0.0892
# Epoch 16 Batch 1300 Loss 0.1365
# Epoch 16 Batch 1400 Loss 0.0870
# Epoch 16 Batch 1500 Loss 0.1116
# Epoch 16 Batch 1600 Loss 0.0860
# Epoch 16 Batch 1700 Loss 0.0898
# Epoch 16 Batch 1800 Loss 0.1098
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 16 Loss 0.0886
# Validation Accuracy 1.0600
# Time taken for 1 epoch 430.9108109474182 sec
#
# Epoch 17 Batch 0 Loss 0.0801
# Epoch 17 Batch 100 Loss 0.0616
# Epoch 17 Batch 200 Loss 0.0684
# Epoch 17 Batch 300 Loss 0.0695
# Epoch 17 Batch 400 Loss 0.0835
# Epoch 17 Batch 500 Loss 0.0635
# Epoch 17 Batch 600 Loss 0.0786
# Epoch 17 Batch 700 Loss 0.0712
# Epoch 17 Batch 800 Loss 0.0827
# Epoch 17 Batch 900 Loss 0.0789
# Epoch 17 Batch 1000 Loss 0.0933
# Epoch 17 Batch 1100 Loss 0.1087
# Epoch 17 Batch 1200 Loss 0.0934
# Epoch 17 Batch 1300 Loss 0.0745
# Epoch 17 Batch 1400 Loss 0.0959
# Epoch 17 Batch 1500 Loss 0.0938
# Epoch 17 Batch 1600 Loss 0.1147
# Epoch 17 Batch 1700 Loss 0.1038
# Epoch 17 Batch 1800 Loss 0.0923
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 17 Loss 0.0848
# Validation Accuracy 1.0100
# Time taken for 1 epoch 441.16508316993713 sec
#
# Epoch 18 Batch 0 Loss 0.0576
# Epoch 18 Batch 100 Loss 0.0613
# Epoch 18 Batch 200 Loss 0.0909
# Epoch 18 Batch 300 Loss 0.0601
# Epoch 18 Batch 400 Loss 0.0651
# Epoch 18 Batch 500 Loss 0.1071
# Epoch 18 Batch 600 Loss 0.0833
# Epoch 18 Batch 700 Loss 0.0787
# Epoch 18 Batch 800 Loss 0.0804
# Epoch 18 Batch 900 Loss 0.0786
# Epoch 18 Batch 1000 Loss 0.0914
# Epoch 18 Batch 1100 Loss 0.0707
# Epoch 18 Batch 1200 Loss 0.1063
# Epoch 18 Batch 1300 Loss 0.0823
# Epoch 18 Batch 1400 Loss 0.0966
# Epoch 18 Batch 1500 Loss 0.0935
# Epoch 18 Batch 1600 Loss 0.0893
# Epoch 18 Batch 1700 Loss 0.1007
# Epoch 18 Batch 1800 Loss 0.0919
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 18 Loss 0.0814
# Validation Accuracy 1.1400
# Time taken for 1 epoch 435.8930923938751 sec
#
# Epoch 19 Batch 0 Loss 0.0675
# Epoch 19 Batch 100 Loss 0.0515
# Epoch 19 Batch 200 Loss 0.0634
# Epoch 19 Batch 300 Loss 0.0725
# Epoch 19 Batch 400 Loss 0.0595
# Epoch 19 Batch 500 Loss 0.0903
# Epoch 19 Batch 600 Loss 0.0823
# Epoch 19 Batch 700 Loss 0.0751
# Epoch 19 Batch 800 Loss 0.0631
# Epoch 19 Batch 900 Loss 0.0792
# Epoch 19 Batch 1000 Loss 0.0771
# Epoch 19 Batch 1100 Loss 0.0801
# Epoch 19 Batch 1200 Loss 0.0590
# Epoch 19 Batch 1300 Loss 0.0936
# Epoch 19 Batch 1400 Loss 0.1044
# Epoch 19 Batch 1500 Loss 0.1009
# Epoch 19 Batch 1600 Loss 0.0874
# Epoch 19 Batch 1700 Loss 0.1072
# Epoch 19 Batch 1800 Loss 0.0971
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 19 Loss 0.0787
# Validation Accuracy 0.9700
# Time taken for 1 epoch 444.51624870300293 sec
#
# Epoch 20 Batch 0 Loss 0.0597
# Epoch 20 Batch 100 Loss 0.0542
# Epoch 20 Batch 200 Loss 0.0553
# Epoch 20 Batch 300 Loss 0.0793
# Epoch 20 Batch 400 Loss 0.0693
# Epoch 20 Batch 500 Loss 0.0594
# Epoch 20 Batch 600 Loss 0.0612
# Epoch 20 Batch 700 Loss 0.0824
# Epoch 20 Batch 800 Loss 0.0899
# Epoch 20 Batch 900 Loss 0.0775
# Epoch 20 Batch 1000 Loss 0.0535
# Epoch 20 Batch 1100 Loss 0.0838
# Epoch 20 Batch 1200 Loss 0.0781
# Epoch 20 Batch 1300 Loss 0.0646
# Epoch 20 Batch 1400 Loss 0.1061
# Epoch 20 Batch 1500 Loss 0.0566
# Epoch 20 Batch 1600 Loss 0.0860
# Epoch 20 Batch 1700 Loss 0.0944
# Epoch 20 Batch 1800 Loss 0.1129
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 20 Loss 0.0762
# Validation Accuracy 1.0400
# Time taken for 1 epoch 430.89204621315 sec
#
# Epoch 21 Batch 0 Loss 0.0540
# Epoch 21 Batch 100 Loss 0.0453
# Epoch 21 Batch 200 Loss 0.0624
# Epoch 21 Batch 300 Loss 0.0495
# Epoch 21 Batch 400 Loss 0.0513
# Epoch 21 Batch 500 Loss 0.0682
# Epoch 21 Batch 600 Loss 0.0494
# Epoch 21 Batch 700 Loss 0.0622
# Epoch 21 Batch 800 Loss 0.0789
# Epoch 21 Batch 900 Loss 0.0851
# Epoch 21 Batch 1000 Loss 0.0795
# Epoch 21 Batch 1100 Loss 0.0893
# Epoch 21 Batch 1200 Loss 0.0522
# Epoch 21 Batch 1300 Loss 0.0754
# Epoch 21 Batch 1400 Loss 0.0789
# Epoch 21 Batch 1500 Loss 0.0950
# Epoch 21 Batch 1600 Loss 0.0826
# Epoch 21 Batch 1700 Loss 0.0872
# Epoch 21 Batch 1800 Loss 0.0737
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 21 Loss 0.0735
# Validation Accuracy 1.1700
# Time taken for 1 epoch 410.7809660434723 sec
#
# Epoch 22 Batch 0 Loss 0.0636
# Epoch 22 Batch 100 Loss 0.0467
# Epoch 22 Batch 200 Loss 0.0638
# Epoch 22 Batch 300 Loss 0.0584
# Epoch 22 Batch 400 Loss 0.0404
# Epoch 22 Batch 500 Loss 0.0547
# Epoch 22 Batch 600 Loss 0.0679
# Epoch 22 Batch 700 Loss 0.0673
# Epoch 22 Batch 800 Loss 0.0641
# Epoch 22 Batch 900 Loss 0.0591
# Epoch 22 Batch 1000 Loss 0.0611
# Epoch 22 Batch 1100 Loss 0.0552
# Epoch 22 Batch 1200 Loss 0.0885
# Epoch 22 Batch 1300 Loss 0.0747
# Epoch 22 Batch 1400 Loss 0.0904
# Epoch 22 Batch 1500 Loss 0.0838
# Epoch 22 Batch 1600 Loss 0.0906
# Epoch 22 Batch 1700 Loss 0.0873
# Epoch 22 Batch 1800 Loss 0.0854
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 22 Loss 0.0720
# Validation Accuracy 1.2400
# Time taken for 1 epoch 416.7413716316223 sec
#
# Epoch 23 Batch 0 Loss 0.0809
# Epoch 23 Batch 100 Loss 0.0392
# Epoch 23 Batch 200 Loss 0.0434
# Epoch 23 Batch 300 Loss 0.0597
# Epoch 23 Batch 400 Loss 0.0582
# Epoch 23 Batch 500 Loss 0.0592
# Epoch 23 Batch 600 Loss 0.0491
# Epoch 23 Batch 700 Loss 0.0972
# Epoch 23 Batch 800 Loss 0.0632
# Epoch 23 Batch 900 Loss 0.0782
# Epoch 23 Batch 1000 Loss 0.0524
# Epoch 23 Batch 1100 Loss 0.0831
# Epoch 23 Batch 1200 Loss 0.0797
# Epoch 23 Batch 1300 Loss 0.0768
# Epoch 23 Batch 1400 Loss 0.0777
# Epoch 23 Batch 1500 Loss 0.0777
# Epoch 23 Batch 1600 Loss 0.0823
# Epoch 23 Batch 1700 Loss 0.0797
# Epoch 23 Batch 1800 Loss 0.0651
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 23 Loss 0.0705
# Validation Accuracy 1.1700
# Time taken for 1 epoch 421.1334135532379 sec
#
# Epoch 24 Batch 0 Loss 0.0483
# Epoch 24 Batch 100 Loss 0.0407
# Epoch 24 Batch 200 Loss 0.0558
# Epoch 24 Batch 300 Loss 0.0561
# Epoch 24 Batch 400 Loss 0.0721
# Epoch 24 Batch 500 Loss 0.0637
# Epoch 24 Batch 600 Loss 0.0485
# Epoch 24 Batch 700 Loss 0.0519
# Epoch 24 Batch 800 Loss 0.0755
# Epoch 24 Batch 900 Loss 0.0578
# Epoch 24 Batch 1000 Loss 0.0781
# Epoch 24 Batch 1100 Loss 0.0759
# Epoch 24 Batch 1200 Loss 0.1082
# Epoch 24 Batch 1300 Loss 0.0771
# Epoch 24 Batch 1400 Loss 0.0864
# Epoch 24 Batch 1500 Loss 0.0945
# Epoch 24 Batch 1600 Loss 0.0731
# Epoch 24 Batch 1700 Loss 0.0619
# Epoch 24 Batch 1800 Loss 0.0589
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 24 Loss 0.0695
# Validation Accuracy 1.2100
# Time taken for 1 epoch 421.4324412345886 sec
#
# Epoch 25 Batch 0 Loss 0.0514
# Epoch 25 Batch 100 Loss 0.0438
# Epoch 25 Batch 200 Loss 0.0452
# Epoch 25 Batch 300 Loss 0.0542
# Epoch 25 Batch 400 Loss 0.0644
# Epoch 25 Batch 500 Loss 0.0535
# Epoch 25 Batch 600 Loss 0.0798
# Epoch 25 Batch 700 Loss 0.0855
# Epoch 25 Batch 800 Loss 0.0634
# Epoch 25 Batch 900 Loss 0.0628
# Epoch 25 Batch 1000 Loss 0.0578
# Epoch 25 Batch 1100 Loss 0.0582
# Epoch 25 Batch 1200 Loss 0.0893
# Epoch 25 Batch 1300 Loss 0.0848
# Epoch 25 Batch 1400 Loss 0.0793
# Epoch 25 Batch 1500 Loss 0.0591
# Epoch 25 Batch 1600 Loss 0.0770
# Epoch 25 Batch 1700 Loss 0.0867
# Epoch 25 Batch 1800 Loss 0.0627
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 25 Loss 0.0679
# Validation Accuracy 1.1100
# Time taken for 1 epoch 426.79765486717224 sec
#
# Epoch 26 Batch 0 Loss 0.0726
# Epoch 26 Batch 100 Loss 0.0466
# Epoch 26 Batch 200 Loss 0.0731
# Epoch 26 Batch 300 Loss 0.0674
# Epoch 26 Batch 400 Loss 0.0742
# Epoch 26 Batch 500 Loss 0.0632
# Epoch 26 Batch 600 Loss 0.0578
# Epoch 26 Batch 700 Loss 0.0667
# Epoch 26 Batch 800 Loss 0.0520
# Epoch 26 Batch 900 Loss 0.0561
# Epoch 26 Batch 1000 Loss 0.0731
# Epoch 26 Batch 1100 Loss 0.0626
# Epoch 26 Batch 1200 Loss 0.0808
# Epoch 26 Batch 1300 Loss 0.0813
# Epoch 26 Batch 1400 Loss 0.0732
# Epoch 26 Batch 1500 Loss 0.0774
# Epoch 26 Batch 1600 Loss 0.0669
# Epoch 26 Batch 1700 Loss 0.0811
# Epoch 26 Batch 1800 Loss 0.0761
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 26 Loss 0.0668
# Validation Accuracy 1.1500
# Time taken for 1 epoch 431.1006193161011 sec
#
# Epoch 27 Batch 0 Loss 0.0790
# Epoch 27 Batch 100 Loss 0.0435
# Epoch 27 Batch 200 Loss 0.0512
# Epoch 27 Batch 300 Loss 0.0531
# Epoch 27 Batch 400 Loss 0.0587
# Epoch 27 Batch 500 Loss 0.0648
# Epoch 27 Batch 600 Loss 0.0638
# Epoch 27 Batch 700 Loss 0.0441
# Epoch 27 Batch 800 Loss 0.0666
# Epoch 27 Batch 900 Loss 0.0851
# Epoch 27 Batch 1000 Loss 0.0723
# Epoch 27 Batch 1100 Loss 0.0720
# Epoch 27 Batch 1200 Loss 0.0632
# Epoch 27 Batch 1300 Loss 0.0643
# Epoch 27 Batch 1400 Loss 0.0589
# Epoch 27 Batch 1500 Loss 0.0650
# Epoch 27 Batch 1600 Loss 0.0821
# Epoch 27 Batch 1700 Loss 0.0650
# Epoch 27 Batch 1800 Loss 0.0961
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 27 Loss 0.0666
# Validation Accuracy 1.1800
# Time taken for 1 epoch 428.3940477371216 sec
#
# Epoch 28 Batch 0 Loss 0.0716
# Epoch 28 Batch 100 Loss 0.0606
# Epoch 28 Batch 200 Loss 0.0570
# Epoch 28 Batch 300 Loss 0.0502
# Epoch 28 Batch 400 Loss 0.0664
# Epoch 28 Batch 500 Loss 0.0403
# Epoch 28 Batch 600 Loss 0.0579
# Epoch 28 Batch 700 Loss 0.0357
# Epoch 28 Batch 800 Loss 0.0631
# Epoch 28 Batch 900 Loss 0.0392
# Epoch 28 Batch 1000 Loss 0.0775
# Epoch 28 Batch 1100 Loss 0.0865
# Epoch 28 Batch 1200 Loss 0.0669
# Epoch 28 Batch 1300 Loss 0.0959
# Epoch 28 Batch 1400 Loss 0.0678
# Epoch 28 Batch 1500 Loss 0.0669
# Epoch 28 Batch 1600 Loss 0.0769
# Epoch 28 Batch 1700 Loss 0.0957
# Epoch 28 Batch 1800 Loss 0.0540
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 28 Loss 0.0651
# Validation Accuracy 1.2000
# Time taken for 1 epoch 429.9453761577606 sec
#
# Epoch 29 Batch 0 Loss 0.0652
# Epoch 29 Batch 100 Loss 0.0367
# Epoch 29 Batch 200 Loss 0.0575
# Epoch 29 Batch 300 Loss 0.0617
# Epoch 29 Batch 400 Loss 0.0464
# Epoch 29 Batch 500 Loss 0.0485
# Epoch 29 Batch 600 Loss 0.0590
# Epoch 29 Batch 700 Loss 0.0620
# Epoch 29 Batch 800 Loss 0.0629
# Epoch 29 Batch 900 Loss 0.0588
# Epoch 29 Batch 1000 Loss 0.0578
# Epoch 29 Batch 1100 Loss 0.0774
# Epoch 29 Batch 1200 Loss 0.0856
# Epoch 29 Batch 1300 Loss 0.0563
# Epoch 29 Batch 1400 Loss 0.0612
# Epoch 29 Batch 1500 Loss 0.1049
# Epoch 29 Batch 1600 Loss 0.0751
# Epoch 29 Batch 1700 Loss 0.0690
# Epoch 29 Batch 1800 Loss 0.0874
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 29 Loss 0.0643
# Validation Accuracy 1.2200
# Time taken for 1 epoch 438.7625346183777 sec
#
# Epoch 30 Batch 0 Loss 0.0653
# Epoch 30 Batch 100 Loss 0.0450
# Epoch 30 Batch 200 Loss 0.0576
# Epoch 30 Batch 300 Loss 0.0480
# Epoch 30 Batch 400 Loss 0.0666
# Epoch 30 Batch 500 Loss 0.0634
# Epoch 30 Batch 600 Loss 0.0833
# Epoch 30 Batch 700 Loss 0.0482
# Epoch 30 Batch 800 Loss 0.0603
# Epoch 30 Batch 900 Loss 0.0604
# Epoch 30 Batch 1000 Loss 0.0818
# Epoch 30 Batch 1100 Loss 0.0744
# Epoch 30 Batch 1200 Loss 0.0554
# Epoch 30 Batch 1300 Loss 0.0629
# Epoch 30 Batch 1400 Loss 0.0773
# Epoch 30 Batch 1500 Loss 0.0897
# Epoch 30 Batch 1600 Loss 0.0678
# Epoch 30 Batch 1700 Loss 0.0777
# Epoch 30 Batch 1800 Loss 0.0950
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 30 Loss 0.0640
# Validation Accuracy 1.0900
# Time taken for 1 epoch 418.42103242874146 sec
#
# Epoch 31 Batch 0 Loss 0.0638
# Epoch 31 Batch 100 Loss 0.0597
# Epoch 31 Batch 200 Loss 0.0627
# Epoch 31 Batch 300 Loss 0.0528
# Epoch 31 Batch 400 Loss 0.0637
# Epoch 31 Batch 500 Loss 0.0508
# Epoch 31 Batch 600 Loss 0.0653
# Epoch 31 Batch 700 Loss 0.0521
# Epoch 31 Batch 800 Loss 0.0549
# Epoch 31 Batch 900 Loss 0.0799
# Epoch 31 Batch 1000 Loss 0.0860
# Epoch 31 Batch 1100 Loss 0.0534
# Epoch 31 Batch 1200 Loss 0.0785
# Epoch 31 Batch 1300 Loss 0.0493
# Epoch 31 Batch 1400 Loss 0.0635
# Epoch 31 Batch 1500 Loss 0.0751
# Epoch 31 Batch 1600 Loss 0.0861
# Epoch 31 Batch 1700 Loss 0.0690
# Epoch 31 Batch 1800 Loss 0.0781
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 31 Loss 0.0640
# Validation Accuracy 1.1400
# Time taken for 1 epoch 414.6081898212433 sec
#
# Epoch 32 Batch 0 Loss 0.0522
# Epoch 32 Batch 100 Loss 0.0459
# Epoch 32 Batch 200 Loss 0.0505
# Epoch 32 Batch 300 Loss 0.0606
# Epoch 32 Batch 400 Loss 0.0424
# Epoch 32 Batch 500 Loss 0.0534
# Epoch 32 Batch 600 Loss 0.0572
# Epoch 32 Batch 700 Loss 0.0739
# Epoch 32 Batch 800 Loss 0.0636
# Epoch 32 Batch 900 Loss 0.0673
# Epoch 32 Batch 1000 Loss 0.0552
# Epoch 32 Batch 1100 Loss 0.0706
# Epoch 32 Batch 1200 Loss 0.0561
# Epoch 32 Batch 1300 Loss 0.0510
# Epoch 32 Batch 1400 Loss 0.0667
# Epoch 32 Batch 1500 Loss 0.0648
# Epoch 32 Batch 1600 Loss 0.0756
# Epoch 32 Batch 1700 Loss 0.0686
# Epoch 32 Batch 1800 Loss 0.0734
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 32 Loss 0.0630
# Validation Accuracy 1.1900
# Time taken for 1 epoch 422.49033188819885 sec
#
# Epoch 33 Batch 0 Loss 0.0625
# Epoch 33 Batch 100 Loss 0.0813
# Epoch 33 Batch 200 Loss 0.0392
# Epoch 33 Batch 300 Loss 0.0513
# Epoch 33 Batch 400 Loss 0.0496
# Epoch 33 Batch 500 Loss 0.0579
# Epoch 33 Batch 600 Loss 0.0557
# Epoch 33 Batch 700 Loss 0.0465
# Epoch 33 Batch 800 Loss 0.0619
# Epoch 33 Batch 900 Loss 0.0585
# Epoch 33 Batch 1000 Loss 0.0816
# Epoch 33 Batch 1100 Loss 0.0649
# Epoch 33 Batch 1200 Loss 0.0504
# Epoch 33 Batch 1300 Loss 0.0638
# Epoch 33 Batch 1400 Loss 0.0589
# Epoch 33 Batch 1500 Loss 0.0686
# Epoch 33 Batch 1600 Loss 0.1024
# Epoch 33 Batch 1700 Loss 0.0647
# Epoch 33 Batch 1800 Loss 0.0674
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 33 Loss 0.0617
# Validation Accuracy 1.1500
# Time taken for 1 epoch 422.8897988796234 sec
#
# Epoch 34 Batch 0 Loss 0.0530
# Epoch 34 Batch 100 Loss 0.0616
# Epoch 34 Batch 200 Loss 0.0371
# Epoch 34 Batch 300 Loss 0.0538
# Epoch 34 Batch 400 Loss 0.0438
# Epoch 34 Batch 500 Loss 0.0457
# Epoch 34 Batch 600 Loss 0.0515
# Epoch 34 Batch 700 Loss 0.0698
# Epoch 34 Batch 800 Loss 0.0635
# Epoch 34 Batch 900 Loss 0.0799
# Epoch 34 Batch 1000 Loss 0.0587
# Epoch 34 Batch 1100 Loss 0.0591
# Epoch 34 Batch 1200 Loss 0.0667
# Epoch 34 Batch 1300 Loss 0.0422
# Epoch 34 Batch 1400 Loss 0.0772
# Epoch 34 Batch 1500 Loss 0.0724
# Epoch 34 Batch 1600 Loss 0.0606
# Epoch 34 Batch 1700 Loss 0.0729
# Epoch 34 Batch 1800 Loss 0.0695
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 34 Loss 0.0626
# Validation Accuracy 1.1200
# Time taken for 1 epoch 421.36469554901123 sec
#
# Epoch 35 Batch 0 Loss 0.0414
# Epoch 35 Batch 100 Loss 0.0403
# Epoch 35 Batch 200 Loss 0.0428
# Epoch 35 Batch 300 Loss 0.0445
# Epoch 35 Batch 400 Loss 0.0440
# Epoch 35 Batch 500 Loss 0.0576
# Epoch 35 Batch 600 Loss 0.0498
# Epoch 35 Batch 700 Loss 0.0605
# Epoch 35 Batch 800 Loss 0.0624
# Epoch 35 Batch 900 Loss 0.0711
# Epoch 35 Batch 1000 Loss 0.0665
# Epoch 35 Batch 1100 Loss 0.0727
# Epoch 35 Batch 1200 Loss 0.0860
# Epoch 35 Batch 1300 Loss 0.0605
# Epoch 35 Batch 1400 Loss 0.0602
# Epoch 35 Batch 1500 Loss 0.0589
# Epoch 35 Batch 1600 Loss 0.0749
# Epoch 35 Batch 1700 Loss 0.0662
# Epoch 35 Batch 1800 Loss 0.0621
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 35 Loss 0.0612
# Validation Accuracy 1.2100
# Time taken for 1 epoch 421.63227128982544 sec
#
# Epoch 36 Batch 0 Loss 0.0569
# Epoch 36 Batch 100 Loss 0.0575
# Epoch 36 Batch 200 Loss 0.0508
# Epoch 36 Batch 300 Loss 0.0461
# Epoch 36 Batch 400 Loss 0.0589
# Epoch 36 Batch 500 Loss 0.0578
# Epoch 36 Batch 600 Loss 0.0537
# Epoch 36 Batch 700 Loss 0.0591
# Epoch 36 Batch 800 Loss 0.0534
# Epoch 36 Batch 900 Loss 0.0657
# Epoch 36 Batch 1000 Loss 0.0820
# Epoch 36 Batch 1100 Loss 0.0548
# Epoch 36 Batch 1200 Loss 0.0758
# Epoch 36 Batch 1300 Loss 0.0820
# Epoch 36 Batch 1400 Loss 0.0793
# Epoch 36 Batch 1500 Loss 0.0702
# Epoch 36 Batch 1600 Loss 0.0916
# Epoch 36 Batch 1700 Loss 0.0649
# Epoch 36 Batch 1800 Loss 0.0866
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 36 Loss 0.0614
# Validation Accuracy 1.1700
# Time taken for 1 epoch 416.93812322616577 sec
#
# Epoch 37 Batch 0 Loss 0.0520
# Epoch 37 Batch 100 Loss 0.0317
# Epoch 37 Batch 200 Loss 0.0469
# Epoch 37 Batch 300 Loss 0.0593
# Epoch 37 Batch 400 Loss 0.0596
# Epoch 37 Batch 500 Loss 0.0689
# Epoch 37 Batch 600 Loss 0.0484
# Epoch 37 Batch 700 Loss 0.0517
# Epoch 37 Batch 800 Loss 0.0669
# Epoch 37 Batch 900 Loss 0.0698
# Epoch 37 Batch 1000 Loss 0.0583
# Epoch 37 Batch 1100 Loss 0.0606
# Epoch 37 Batch 1200 Loss 0.0771
# Epoch 37 Batch 1300 Loss 0.0824
# Epoch 37 Batch 1400 Loss 0.0868
# Epoch 37 Batch 1500 Loss 0.0636
# Epoch 37 Batch 1600 Loss 0.0826
# Epoch 37 Batch 1700 Loss 0.0554
# Epoch 37 Batch 1800 Loss 0.0543
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 37 Loss 0.0606
# Validation Accuracy 1.2100
# Time taken for 1 epoch 422.92170310020447 sec
#
# Epoch 38 Batch 0 Loss 0.0487
# Epoch 38 Batch 100 Loss 0.0546
# Epoch 38 Batch 200 Loss 0.0472
# Epoch 38 Batch 300 Loss 0.0359
# Epoch 38 Batch 400 Loss 0.0481
# Epoch 38 Batch 500 Loss 0.0529
# Epoch 38 Batch 600 Loss 0.0597
# Epoch 38 Batch 700 Loss 0.0604
# Epoch 38 Batch 800 Loss 0.0701
# Epoch 38 Batch 900 Loss 0.0550
# Epoch 38 Batch 1000 Loss 0.0440
# Epoch 38 Batch 1100 Loss 0.0706
# Epoch 38 Batch 1200 Loss 0.0599
# Epoch 38 Batch 1300 Loss 0.0886
# Epoch 38 Batch 1400 Loss 0.0602
# Epoch 38 Batch 1500 Loss 0.0875
# Epoch 38 Batch 1600 Loss 0.0709
# Epoch 38 Batch 1700 Loss 0.0732
# Epoch 38 Batch 1800 Loss 0.0593
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 38 Loss 0.0599
# Validation Accuracy 1.1600
# Time taken for 1 epoch 418.8113708496094 sec
# Epoch 39 Batch 0 Loss 0.0552
# Epoch 39 Batch 100 Loss 0.0432
# Epoch 39 Batch 200 Loss 0.0318
# Epoch 39 Batch 300 Loss 0.0641
# Epoch 39 Batch 400 Loss 0.0526
# Epoch 39 Batch 500 Loss 0.0619
# Epoch 39 Batch 600 Loss 0.0556
# Epoch 39 Batch 700 Loss 0.0669
# Epoch 39 Batch 800 Loss 0.0608
# Epoch 39 Batch 900 Loss 0.0594
# Epoch 39 Batch 1000 Loss 0.0603
# Epoch 39 Batch 1100 Loss 0.0810
# Epoch 39 Batch 1200 Loss 0.0761
# Epoch 39 Batch 1300 Loss 0.0874
# Epoch 39 Batch 1400 Loss 0.0670
# Epoch 39 Batch 1500 Loss 0.0593
# Epoch 39 Batch 1600 Loss 0.0935
# Epoch 39 Batch 1700 Loss 0.0581
# Epoch 39 Batch 1800 Loss 0.0616
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 39 Loss 0.0597
# Validation Accuracy 1.2200
# Time taken for 1 epoch 422.05377650260925 sec
#
# Epoch 40 Batch 0 Loss 0.0393
# Epoch 40 Batch 100 Loss 0.0560
# Epoch 40 Batch 200 Loss 0.0520
# Epoch 40 Batch 300 Loss 0.0640
# Epoch 40 Batch 400 Loss 0.0560
# Epoch 40 Batch 500 Loss 0.0741
# Epoch 40 Batch 600 Loss 0.0649
# Epoch 40 Batch 700 Loss 0.0558
# Epoch 40 Batch 800 Loss 0.0474
# Epoch 40 Batch 900 Loss 0.0520
# Epoch 40 Batch 1000 Loss 0.0425
# Epoch 40 Batch 1100 Loss 0.0779
# Epoch 40 Batch 1200 Loss 0.0628
# Epoch 40 Batch 1300 Loss 0.0581
# Epoch 40 Batch 1400 Loss 0.0769
# Epoch 40 Batch 1500 Loss 0.0662
# Epoch 40 Batch 1600 Loss 0.0741
# Epoch 40 Batch 1700 Loss 0.0760
# Epoch 40 Batch 1800 Loss 0.0461
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 40 Loss 0.0600
# Validation Accuracy 1.1500
# Time taken for 1 epoch 423.53154373168945 sec
#
# Epoch 41 Batch 0 Loss 0.0537
# Epoch 41 Batch 100 Loss 0.0680
# Epoch 41 Batch 200 Loss 0.0374
# Epoch 41 Batch 300 Loss 0.0474
# Epoch 41 Batch 400 Loss 0.0476
# Epoch 41 Batch 500 Loss 0.0559
# Epoch 41 Batch 600 Loss 0.0496
# Epoch 41 Batch 700 Loss 0.0595
# Epoch 41 Batch 800 Loss 0.0815
# Epoch 41 Batch 900 Loss 0.0404
# Epoch 41 Batch 1000 Loss 0.0714
# Epoch 41 Batch 1100 Loss 0.0689
# Epoch 41 Batch 1200 Loss 0.0688
# Epoch 41 Batch 1300 Loss 0.0892
# Epoch 41 Batch 1400 Loss 0.0740
# Epoch 41 Batch 1500 Loss 0.0638
# Epoch 41 Batch 1600 Loss 0.0524
# Epoch 41 Batch 1700 Loss 0.0605
# Epoch 41 Batch 1800 Loss 0.0772
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 41 Loss 0.0598
# Validation Accuracy 1.1300
# Time taken for 1 epoch 422.907000541687 sec
#
# Epoch 42 Batch 0 Loss 0.0561
# Epoch 42 Batch 100 Loss 0.0641
# Epoch 42 Batch 200 Loss 0.0358
# Epoch 42 Batch 300 Loss 0.0644
# Epoch 42 Batch 400 Loss 0.0394
# Epoch 42 Batch 500 Loss 0.0748
# Epoch 42 Batch 600 Loss 0.0825
# Epoch 42 Batch 700 Loss 0.0430
# Epoch 42 Batch 800 Loss 0.0604
# Epoch 42 Batch 900 Loss 0.0508
# Epoch 42 Batch 1000 Loss 0.0535
# Epoch 42 Batch 1100 Loss 0.0595
# Epoch 42 Batch 1200 Loss 0.0702
# Epoch 42 Batch 1300 Loss 0.0738
# Epoch 42 Batch 1400 Loss 0.0625
# Epoch 42 Batch 1500 Loss 0.0674
# Epoch 42 Batch 1600 Loss 0.0871
# Epoch 42 Batch 1700 Loss 0.0814
# Epoch 42 Batch 1800 Loss 0.0970
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 42 Loss 0.0596
# Validation Accuracy 1.3300
# Time taken for 1 epoch 421.0534837245941 sec
#
# Epoch 43 Batch 0 Loss 0.0502
# Epoch 43 Batch 100 Loss 0.0439
# Epoch 43 Batch 200 Loss 0.0499
# Epoch 43 Batch 300 Loss 0.0514
# Epoch 43 Batch 400 Loss 0.0724
# Epoch 43 Batch 500 Loss 0.0568
# Epoch 43 Batch 600 Loss 0.0473
# Epoch 43 Batch 700 Loss 0.0360
# Epoch 43 Batch 800 Loss 0.0640
# Epoch 43 Batch 900 Loss 0.0745
# Epoch 43 Batch 1000 Loss 0.0523
# Epoch 43 Batch 1100 Loss 0.0466
# Epoch 43 Batch 1200 Loss 0.0712
# Epoch 43 Batch 1300 Loss 0.0851
# Epoch 43 Batch 1400 Loss 0.0612
# Epoch 43 Batch 1500 Loss 0.0749
# Epoch 43 Batch 1600 Loss 0.0723
# Epoch 43 Batch 1700 Loss 0.0691
# Epoch 43 Batch 1800 Loss 0.0694
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 43 Loss 0.0573
# Validation Accuracy 1.3700
# Time taken for 1 epoch 421.21193838119507 sec
#
# Epoch 44 Batch 0 Loss 0.0401
# Epoch 44 Batch 100 Loss 0.0355
# Epoch 44 Batch 200 Loss 0.0368
# Epoch 44 Batch 300 Loss 0.0370
# Epoch 44 Batch 400 Loss 0.0341
# Epoch 44 Batch 500 Loss 0.0510
# Epoch 44 Batch 600 Loss 0.0598
# Epoch 44 Batch 700 Loss 0.0621
# Epoch 44 Batch 800 Loss 0.0575
# Epoch 44 Batch 900 Loss 0.0409
# Epoch 44 Batch 1000 Loss 0.0549
# Epoch 44 Batch 1100 Loss 0.0618
# Epoch 44 Batch 1200 Loss 0.0630
# Epoch 44 Batch 1300 Loss 0.0649
# Epoch 44 Batch 1400 Loss 0.0637
# Epoch 44 Batch 1500 Loss 0.0882
# Epoch 44 Batch 1600 Loss 0.0900
# Epoch 44 Batch 1700 Loss 0.0649
# Epoch 44 Batch 1800 Loss 0.0862
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 44 Loss 0.0594
# Validation Accuracy 1.1800
# Time taken for 1 epoch 421.90399837493896 sec
#
# Epoch 45 Batch 0 Loss 0.0658
# Epoch 45 Batch 100 Loss 0.0528
# Epoch 45 Batch 200 Loss 0.0579
# Epoch 45 Batch 300 Loss 0.0488
# Epoch 45 Batch 400 Loss 0.0517
# Epoch 45 Batch 500 Loss 0.0432
# Epoch 45 Batch 600 Loss 0.0450
# Epoch 45 Batch 700 Loss 0.0526
# Epoch 45 Batch 800 Loss 0.0750
# Epoch 45 Batch 900 Loss 0.0774
# Epoch 45 Batch 1000 Loss 0.0599
# Epoch 45 Batch 1100 Loss 0.0617
# Epoch 45 Batch 1200 Loss 0.0575
# Epoch 45 Batch 1300 Loss 0.0888
# Epoch 45 Batch 1400 Loss 0.0493
# Epoch 45 Batch 1500 Loss 0.0825
# Epoch 45 Batch 1600 Loss 0.0650
# Epoch 45 Batch 1700 Loss 0.0612
# Epoch 45 Batch 1800 Loss 0.0463
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 45 Loss 0.0578
# Validation Accuracy 1.1200
# Time taken for 1 epoch 422.13409209251404 sec
#
# Epoch 46 Batch 0 Loss 0.0550
# Epoch 46 Batch 100 Loss 0.0500
# Epoch 46 Batch 200 Loss 0.0575
# Epoch 46 Batch 300 Loss 0.0402
# Epoch 46 Batch 400 Loss 0.0352
# Epoch 46 Batch 500 Loss 0.0535
# Epoch 46 Batch 600 Loss 0.0429
# Epoch 46 Batch 700 Loss 0.0457
# Epoch 46 Batch 800 Loss 0.0480
# Epoch 46 Batch 900 Loss 0.0611
# Epoch 46 Batch 1000 Loss 0.0480
# Epoch 46 Batch 1100 Loss 0.0697
# Epoch 46 Batch 1200 Loss 0.0960
# Epoch 46 Batch 1300 Loss 0.0810
# Epoch 46 Batch 1400 Loss 0.0717
# Epoch 46 Batch 1500 Loss 0.0678
# Epoch 46 Batch 1600 Loss 0.0912
# Epoch 46 Batch 1700 Loss 0.0734
# Epoch 46 Batch 1800 Loss 0.0632
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 46 Loss 0.0588
# Validation Accuracy 1.2000
# Time taken for 1 epoch 422.2989900112152 sec
#
# Epoch 47 Batch 0 Loss 0.0638
# Epoch 47 Batch 100 Loss 0.0283
# Epoch 47 Batch 200 Loss 0.0361
# Epoch 47 Batch 300 Loss 0.0455
# Epoch 47 Batch 400 Loss 0.0472
# Epoch 47 Batch 500 Loss 0.0473
# Epoch 47 Batch 600 Loss 0.0381
# Epoch 47 Batch 700 Loss 0.0444
# Epoch 47 Batch 800 Loss 0.0513
# Epoch 47 Batch 900 Loss 0.0608
# Epoch 47 Batch 1000 Loss 0.0556
# Epoch 47 Batch 1100 Loss 0.0502
# Epoch 47 Batch 1200 Loss 0.0710
# Epoch 47 Batch 1300 Loss 0.0599
# Epoch 47 Batch 1400 Loss 0.0571
# Epoch 47 Batch 1500 Loss 0.0621
# Epoch 47 Batch 1600 Loss 0.0544
# Epoch 47 Batch 1700 Loss 0.0972
# Epoch 47 Batch 1800 Loss 0.1013
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 47 Loss 0.0572
# Validation Accuracy 1.2200
# Time taken for 1 epoch 422.72313117980957 sec
#
# Epoch 48 Batch 0 Loss 0.0411
# Epoch 48 Batch 100 Loss 0.0359
# Epoch 48 Batch 200 Loss 0.0479
# Epoch 48 Batch 300 Loss 0.0328
# Epoch 48 Batch 400 Loss 0.0452
# Epoch 48 Batch 500 Loss 0.0627
# Epoch 48 Batch 600 Loss 0.0493
# Epoch 48 Batch 700 Loss 0.0457
# Epoch 48 Batch 800 Loss 0.0698
# Epoch 48 Batch 900 Loss 0.0656
# Epoch 48 Batch 1000 Loss 0.0716
# Epoch 48 Batch 1100 Loss 0.0753
# Epoch 48 Batch 1200 Loss 0.0505
# Epoch 48 Batch 1300 Loss 0.0701
# Epoch 48 Batch 1400 Loss 0.0650
# Epoch 48 Batch 1500 Loss 0.0807
# Epoch 48 Batch 1600 Loss 0.0698
# Epoch 48 Batch 1700 Loss 0.0719
# Epoch 48 Batch 1800 Loss 0.0556
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 48 Loss 0.0571
# Validation Accuracy 1.2000
# Time taken for 1 epoch 421.4986927509308 sec
#
# Epoch 49 Batch 0 Loss 0.0575
# Epoch 49 Batch 100 Loss 0.0691
# Epoch 49 Batch 200 Loss 0.0521
# Epoch 49 Batch 300 Loss 0.0698
# Epoch 49 Batch 400 Loss 0.0629
# Epoch 49 Batch 500 Loss 0.0410
# Epoch 49 Batch 600 Loss 0.0525
# Epoch 49 Batch 700 Loss 0.0765
# Epoch 49 Batch 800 Loss 0.0486
# Epoch 49 Batch 900 Loss 0.0478
# Epoch 49 Batch 1000 Loss 0.0408
# Epoch 49 Batch 1100 Loss 0.0614
# Epoch 49 Batch 1200 Loss 0.0608
# Epoch 49 Batch 1300 Loss 0.0716
# Epoch 49 Batch 1400 Loss 0.0752
# Epoch 49 Batch 1500 Loss 0.0638
# Epoch 49 Batch 1600 Loss 0.0651
# Epoch 49 Batch 1700 Loss 0.0662
# Epoch 49 Batch 1800 Loss 0.0605
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 49 Loss 0.0572
# Validation Accuracy 1.2100
# Time taken for 1 epoch 423.2218632698059 sec
#
# Epoch 50 Batch 0 Loss 0.0482
# Epoch 50 Batch 100 Loss 0.0673
# Epoch 50 Batch 200 Loss 0.0533
# Epoch 50 Batch 300 Loss 0.0431
# Epoch 50 Batch 400 Loss 0.0490
# Epoch 50 Batch 500 Loss 0.0493
# Epoch 50 Batch 600 Loss 0.0488
# Epoch 50 Batch 700 Loss 0.0707
# Epoch 50 Batch 800 Loss 0.0658
# Epoch 50 Batch 900 Loss 0.0572
# Epoch 50 Batch 1000 Loss 0.0557
# Epoch 50 Batch 1100 Loss 0.0603
# Epoch 50 Batch 1200 Loss 0.0674
# Epoch 50 Batch 1300 Loss 0.0424
# Epoch 50 Batch 1400 Loss 0.0763
# Epoch 50 Batch 1500 Loss 0.0810
# Epoch 50 Batch 1600 Loss 0.0713
# Epoch 50 Batch 1700 Loss 0.0463
# Epoch 50 Batch 1800 Loss 0.0449
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 50 Loss 0.0571
# Validation Accuracy 1.2300
# Time taken for 1 epoch 421.6844325065613 sec
#
# Epoch 51 Batch 0 Loss 0.0452
# Epoch 51 Batch 100 Loss 0.0413
# Epoch 51 Batch 200 Loss 0.0418
# Epoch 51 Batch 300 Loss 0.0361
# Epoch 51 Batch 400 Loss 0.0345
# Epoch 51 Batch 500 Loss 0.0458
# Epoch 51 Batch 600 Loss 0.0458
# Epoch 51 Batch 700 Loss 0.0557
# Epoch 51 Batch 800 Loss 0.0510
# Epoch 51 Batch 900 Loss 0.0420
# Epoch 51 Batch 1000 Loss 0.0751
# Epoch 51 Batch 1100 Loss 0.0466
# Epoch 51 Batch 1200 Loss 0.0807
# Epoch 51 Batch 1300 Loss 0.0662
# Epoch 51 Batch 1400 Loss 0.0684
# Epoch 51 Batch 1500 Loss 0.0602
# Epoch 51 Batch 1600 Loss 0.0735
# Epoch 51 Batch 1700 Loss 0.0493
# Epoch 51 Batch 1800 Loss 0.0723
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 51 Loss 0.0568
# Validation Accuracy 1.0800
# Time taken for 1 epoch 423.35214948654175 sec
#
# Epoch 52 Batch 0 Loss 0.0706
# Epoch 52 Batch 100 Loss 0.0528
# Epoch 52 Batch 200 Loss 0.0526
# Epoch 52 Batch 300 Loss 0.0454
# Epoch 52 Batch 400 Loss 0.0376
# Epoch 52 Batch 500 Loss 0.0502
# Epoch 52 Batch 600 Loss 0.0495
# Epoch 52 Batch 700 Loss 0.0379
# Epoch 52 Batch 800 Loss 0.0454
# Epoch 52 Batch 900 Loss 0.0528
# Epoch 52 Batch 1000 Loss 0.0459
# Epoch 52 Batch 1100 Loss 0.0612
# Epoch 52 Batch 1200 Loss 0.0488
# Epoch 52 Batch 1300 Loss 0.0698
# Epoch 52 Batch 1400 Loss 0.0538
# Epoch 52 Batch 1500 Loss 0.0774
# Epoch 52 Batch 1600 Loss 0.0505
# Epoch 52 Batch 1700 Loss 0.0482
# Epoch 52 Batch 1800 Loss 0.0717
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 52 Loss 0.0550
# Validation Accuracy 1.1400
# Time taken for 1 epoch 423.5813708305359 sec
#
# Epoch 53 Batch 0 Loss 0.0591
# Epoch 53 Batch 100 Loss 0.0395
# Epoch 53 Batch 200 Loss 0.0485
# Epoch 53 Batch 300 Loss 0.0465
# Epoch 53 Batch 400 Loss 0.0368
# Epoch 53 Batch 500 Loss 0.0401
# Epoch 53 Batch 600 Loss 0.0505
# Epoch 53 Batch 700 Loss 0.0348
# Epoch 53 Batch 800 Loss 0.0551
# Epoch 53 Batch 900 Loss 0.0738
# Epoch 53 Batch 1000 Loss 0.0477
# Epoch 53 Batch 1100 Loss 0.0685
# Epoch 53 Batch 1200 Loss 0.0428
# Epoch 53 Batch 1300 Loss 0.0722
# Epoch 53 Batch 1400 Loss 0.0567
# Epoch 53 Batch 1500 Loss 0.0495
# Epoch 53 Batch 1600 Loss 0.0582
# Epoch 53 Batch 1700 Loss 0.0877
# Epoch 53 Batch 1800 Loss 0.0539
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 53 Loss 0.0565
# Validation Accuracy 1.2200
# Time taken for 1 epoch 424.40876150131226 sec
#
# Epoch 54 Batch 0 Loss 0.0396
# Epoch 54 Batch 100 Loss 0.0464
# Epoch 54 Batch 200 Loss 0.0478
# Epoch 54 Batch 300 Loss 0.0533
# Epoch 54 Batch 400 Loss 0.0583
# Epoch 54 Batch 500 Loss 0.0418
# Epoch 54 Batch 600 Loss 0.0431
# Epoch 54 Batch 700 Loss 0.0542
# Epoch 54 Batch 800 Loss 0.0492
# Epoch 54 Batch 900 Loss 0.0483
# Epoch 54 Batch 1000 Loss 0.0501
# Epoch 54 Batch 1100 Loss 0.0621
# Epoch 54 Batch 1200 Loss 0.0441
# Epoch 54 Batch 1300 Loss 0.0680
# Epoch 54 Batch 1400 Loss 0.0614
# Epoch 54 Batch 1500 Loss 0.0728
# Epoch 54 Batch 1600 Loss 0.0797
# Epoch 54 Batch 1700 Loss 0.0765
# Epoch 54 Batch 1800 Loss 0.0664
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 54 Loss 0.0564
# Validation Accuracy 1.2100
# Time taken for 1 epoch 419.8982229232788 sec
#
# Epoch 55 Batch 0 Loss 0.0638
# Epoch 55 Batch 100 Loss 0.0431
# Epoch 55 Batch 200 Loss 0.0466
# Epoch 55 Batch 300 Loss 0.0369
# Epoch 55 Batch 400 Loss 0.0399
# Epoch 55 Batch 500 Loss 0.0567
# Epoch 55 Batch 600 Loss 0.0514
# Epoch 55 Batch 700 Loss 0.0571
# Epoch 55 Batch 800 Loss 0.0535
# Epoch 55 Batch 900 Loss 0.0535
# Epoch 55 Batch 1000 Loss 0.0590
# Epoch 55 Batch 1100 Loss 0.0533
# Epoch 55 Batch 1200 Loss 0.0630
# Epoch 55 Batch 1300 Loss 0.0570
# Epoch 55 Batch 1400 Loss 0.0754
# Epoch 55 Batch 1500 Loss 0.0712
# Epoch 55 Batch 1600 Loss 0.0813
# Epoch 55 Batch 1700 Loss 0.0727
# Epoch 55 Batch 1800 Loss 0.0965
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 55 Loss 0.0550
# Validation Accuracy 1.2400
# Time taken for 1 epoch 413.1060218811035 sec
#
# Epoch 56 Batch 0 Loss 0.0410
# Epoch 56 Batch 100 Loss 0.0279
# Epoch 56 Batch 200 Loss 0.0345
# Epoch 56 Batch 300 Loss 0.0623
# Epoch 56 Batch 400 Loss 0.0520
# Epoch 56 Batch 500 Loss 0.0598
# Epoch 56 Batch 600 Loss 0.0520
# Epoch 56 Batch 700 Loss 0.0563
# Epoch 56 Batch 800 Loss 0.0743
# Epoch 56 Batch 900 Loss 0.0575
# Epoch 56 Batch 1000 Loss 0.0754
# ...
# Epoch 80 Batch 1500 Loss 0.0507
# Epoch 80 Batch 1600 Loss 0.0412
# Epoch 80 Batch 1700 Loss 0.0661
# Epoch 80 Batch 1800 Loss 0.0611
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 80 Loss 0.0514
# Validation Accuracy 1.1700
# Time taken for 1 epoch 420.668416261673 sec
#
# Epoch 81 Batch 0 Loss 0.0440
# Epoch 81 Batch 100 Loss 0.0434
# Epoch 81 Batch 200 Loss 0.0430
# Epoch 81 Batch 300 Loss 0.0390
# Epoch 81 Batch 400 Loss 0.0399
# Epoch 81 Batch 500 Loss 0.0403
# Epoch 81 Batch 600 Loss 0.0850
# Epoch 81 Batch 700 Loss 0.0523
# Epoch 81 Batch 800 Loss 0.0605
# Epoch 81 Batch 900 Loss 0.0525
# Epoch 81 Batch 1000 Loss 0.0406
# Epoch 81 Batch 1100 Loss 0.0537
# Epoch 81 Batch 1200 Loss 0.0702
# Epoch 81 Batch 1300 Loss 0.0572
# Epoch 81 Batch 1400 Loss 0.0661
# Epoch 81 Batch 1500 Loss 0.0596
# Epoch 81 Batch 1600 Loss 0.0746
# Epoch 81 Batch 1700 Loss 0.0524
# Epoch 81 Batch 1800 Loss 0.0605
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 81 Loss 0.0526
# Validation Accuracy 1.1800
# Time taken for 1 epoch 421.4437382221222 sec
#
# Epoch 82 Batch 0 Loss 0.0420
# Epoch 82 Batch 100 Loss 0.0447
# Epoch 82 Batch 200 Loss 0.0541
# Epoch 82 Batch 300 Loss 0.0537
# Epoch 82 Batch 400 Loss 0.0393
# Epoch 82 Batch 500 Loss 0.0388
# Epoch 82 Batch 600 Loss 0.0374
# Epoch 82 Batch 700 Loss 0.0407
# Epoch 82 Batch 800 Loss 0.0466
# Epoch 82 Batch 900 Loss 0.0424
# Epoch 82 Batch 1000 Loss 0.0350
# Epoch 82 Batch 1100 Loss 0.0347
# Epoch 82 Batch 1200 Loss 0.0686
# Epoch 82 Batch 1300 Loss 0.0575
# Epoch 82 Batch 1400 Loss 0.0386
# Epoch 82 Batch 1500 Loss 0.0513
# Epoch 82 Batch 1600 Loss 0.0782
# Epoch 82 Batch 1700 Loss 0.0825
# Epoch 82 Batch 1800 Loss 0.0797
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 82 Loss 0.0526
# Validation Accuracy 1.0900
# Time taken for 1 epoch 416.17854619026184 sec
#
# Epoch 83 Batch 0 Loss 0.0358
# Epoch 83 Batch 100 Loss 0.0412
# Epoch 83 Batch 200 Loss 0.0402
# Epoch 83 Batch 300 Loss 0.0393
# Epoch 83 Batch 400 Loss 0.0385
# Epoch 83 Batch 500 Loss 0.0606
# Epoch 83 Batch 600 Loss 0.0584
# Epoch 83 Batch 700 Loss 0.0375
# Epoch 83 Batch 800 Loss 0.0588
# Epoch 83 Batch 900 Loss 0.0609
# Epoch 83 Batch 1000 Loss 0.0404
# Epoch 83 Batch 1100 Loss 0.0520
# Epoch 83 Batch 1200 Loss 0.0716
# Epoch 83 Batch 1300 Loss 0.0436
# Epoch 83 Batch 1400 Loss 0.0701
# Epoch 83 Batch 1500 Loss 0.0532
# Epoch 83 Batch 1600 Loss 0.0691
# Epoch 83 Batch 1700 Loss 0.0600
# Epoch 83 Batch 1800 Loss 0.0664
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 83 Loss 0.0519
# Validation Accuracy 1.1000
# Time taken for 1 epoch 420.11473965644836 sec
#
# Epoch 84 Batch 0 Loss 0.0638
# Epoch 84 Batch 100 Loss 0.0361
# Epoch 84 Batch 200 Loss 0.0237
# Epoch 84 Batch 300 Loss 0.0610
# Epoch 84 Batch 400 Loss 0.0353
# Epoch 84 Batch 500 Loss 0.0540
# Epoch 84 Batch 600 Loss 0.0416
# Epoch 84 Batch 700 Loss 0.0441
# Epoch 84 Batch 800 Loss 0.0647
# Epoch 84 Batch 900 Loss 0.0443
# Epoch 84 Batch 1000 Loss 0.0426
# Epoch 84 Batch 1100 Loss 0.0383
# Epoch 84 Batch 1200 Loss 0.0588
# Epoch 84 Batch 1300 Loss 0.0451
# Epoch 84 Batch 1400 Loss 0.0520
# Epoch 84 Batch 1500 Loss 0.0712
# Epoch 84 Batch 1600 Loss 0.0551
# Epoch 84 Batch 1700 Loss 0.0468
# Epoch 84 Batch 1800 Loss 0.0646
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 84 Loss 0.0529
# Validation Accuracy 1.1300
# Time taken for 1 epoch 423.742484331131 sec
#
# Epoch 85 Batch 0 Loss 0.0465
# Epoch 85 Batch 100 Loss 0.0478
# Epoch 85 Batch 200 Loss 0.0542
# Epoch 85 Batch 300 Loss 0.0520
# Epoch 85 Batch 400 Loss 0.0417
# Epoch 85 Batch 500 Loss 0.0549
# Epoch 85 Batch 600 Loss 0.0352
# Epoch 85 Batch 700 Loss 0.0428
# Epoch 85 Batch 800 Loss 0.0470
# Epoch 85 Batch 900 Loss 0.0630
# Epoch 85 Batch 1000 Loss 0.0632
# Epoch 85 Batch 1100 Loss 0.0568
# Epoch 85 Batch 1200 Loss 0.0513
# Epoch 85 Batch 1300 Loss 0.0433
# Epoch 85 Batch 1400 Loss 0.0635
# Epoch 85 Batch 1500 Loss 0.0624
# Epoch 85 Batch 1600 Loss 0.0718
# Epoch 85 Batch 1700 Loss 0.0639
# Epoch 85 Batch 1800 Loss 0.0576
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 85 Loss 0.0515
# Validation Accuracy 1.0800
# Time taken for 1 epoch 423.82920503616333 sec
#
# Epoch 86 Batch 0 Loss 0.0383
# Epoch 86 Batch 100 Loss 0.0568
# Epoch 86 Batch 200 Loss 0.0425
# Epoch 86 Batch 300 Loss 0.0527
# Epoch 86 Batch 400 Loss 0.0370
# Epoch 86 Batch 500 Loss 0.0342
# Epoch 86 Batch 600 Loss 0.0623
# Epoch 86 Batch 700 Loss 0.0347
# Epoch 86 Batch 800 Loss 0.0519
# Epoch 86 Batch 900 Loss 0.0444
# Epoch 86 Batch 1000 Loss 0.0562
# Epoch 86 Batch 1100 Loss 0.0488
# Epoch 86 Batch 1200 Loss 0.0700
# Epoch 86 Batch 1300 Loss 0.0504
# Epoch 86 Batch 1400 Loss 0.0536
# Epoch 86 Batch 1500 Loss 0.0638
# Epoch 86 Batch 1600 Loss 0.0682
# Epoch 86 Batch 1700 Loss 0.0359
# Epoch 86 Batch 1800 Loss 0.0423
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 86 Loss 0.0513
# Validation Accuracy 1.0700
# Time taken for 1 epoch 423.33358550071716 sec
#
# Epoch 87 Batch 0 Loss 0.0438
# Epoch 87 Batch 100 Loss 0.0375
# Epoch 87 Batch 200 Loss 0.0433
# Epoch 87 Batch 300 Loss 0.0347
# Epoch 87 Batch 400 Loss 0.0570
# Epoch 87 Batch 500 Loss 0.0523
# Epoch 87 Batch 600 Loss 0.0573
# Epoch 87 Batch 700 Loss 0.0688
# Epoch 87 Batch 800 Loss 0.0358
# Epoch 87 Batch 900 Loss 0.0497
# Epoch 87 Batch 1000 Loss 0.0586
# Epoch 87 Batch 1100 Loss 0.0583
# Epoch 87 Batch 1200 Loss 0.0467
# Epoch 87 Batch 1300 Loss 0.0610
# Epoch 87 Batch 1400 Loss 0.0687
# Epoch 87 Batch 1500 Loss 0.0421
# Epoch 87 Batch 1600 Loss 0.0734
# Epoch 87 Batch 1700 Loss 0.0571
# Epoch 87 Batch 1800 Loss 0.0703
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 87 Loss 0.0529
# Validation Accuracy 1.1400
# Time taken for 1 epoch 426.17071747779846 sec
#
# Epoch 88 Batch 0 Loss 0.0326
# Epoch 88 Batch 100 Loss 0.0442
# Epoch 88 Batch 200 Loss 0.0446
# Epoch 88 Batch 300 Loss 0.0621
# Epoch 88 Batch 400 Loss 0.0400
# Epoch 88 Batch 500 Loss 0.0497
# Epoch 88 Batch 600 Loss 0.0556
# Epoch 88 Batch 700 Loss 0.0536
# Epoch 88 Batch 800 Loss 0.0470
# Epoch 88 Batch 900 Loss 0.0649
# Epoch 88 Batch 1000 Loss 0.0503
# Epoch 88 Batch 1100 Loss 0.0444
# Epoch 88 Batch 1200 Loss 0.0705
# Epoch 88 Batch 1300 Loss 0.0606
# Epoch 88 Batch 1400 Loss 0.0553
# Epoch 88 Batch 1500 Loss 0.0656
# Epoch 88 Batch 1600 Loss 0.0598
# Epoch 88 Batch 1700 Loss 0.0821
# Epoch 88 Batch 1800 Loss 0.0443
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 88 Loss 0.0508
# Validation Accuracy 1.2400
# Time taken for 1 epoch 421.41367983818054 sec
#
# Epoch 89 Batch 0 Loss 0.0466
# Epoch 89 Batch 100 Loss 0.0292
# Epoch 89 Batch 200 Loss 0.0321
# Epoch 89 Batch 300 Loss 0.0606
# Epoch 89 Batch 400 Loss 0.0456
# Epoch 89 Batch 500 Loss 0.0599
# Epoch 89 Batch 600 Loss 0.0537
# Epoch 89 Batch 700 Loss 0.0524
# Epoch 89 Batch 800 Loss 0.0441
# Epoch 89 Batch 900 Loss 0.0649
# Epoch 89 Batch 1000 Loss 0.0577
# Epoch 89 Batch 1100 Loss 0.0472
# Epoch 89 Batch 1200 Loss 0.0618
# Epoch 89 Batch 1300 Loss 0.0583
# Epoch 89 Batch 1400 Loss 0.0348
# Epoch 89 Batch 1500 Loss 0.0546
# Epoch 89 Batch 1600 Loss 0.0688
# Epoch 89 Batch 1700 Loss 0.0686
# Epoch 89 Batch 1800 Loss 0.0581
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 89 Loss 0.0515
# Validation Accuracy 1.1900
# Time taken for 1 epoch 418.0092213153839 sec
#
# Epoch 90 Batch 0 Loss 0.0320
# Epoch 90 Batch 100 Loss 0.0480
# Epoch 90 Batch 200 Loss 0.0487
# Epoch 90 Batch 300 Loss 0.0593
# Epoch 90 Batch 400 Loss 0.0534
# Epoch 90 Batch 500 Loss 0.0465
# Epoch 90 Batch 600 Loss 0.0308
# Epoch 90 Batch 700 Loss 0.0583
# Epoch 90 Batch 800 Loss 0.0452
# Epoch 90 Batch 900 Loss 0.0451
# Epoch 90 Batch 1000 Loss 0.0465
# Epoch 90 Batch 1100 Loss 0.0622
# Epoch 90 Batch 1200 Loss 0.0463
# Epoch 90 Batch 1300 Loss 0.0615
# Epoch 90 Batch 1400 Loss 0.0511
# Epoch 90 Batch 1500 Loss 0.0472
# Epoch 90 Batch 1600 Loss 0.0555
# Epoch 90 Batch 1700 Loss 0.0524
# Epoch 90 Batch 1800 Loss 0.0363
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 90 Loss 0.0514
# Validation Accuracy 1.2100
# Time taken for 1 epoch 420.6270399093628 sec
#
# Epoch 91 Batch 0 Loss 0.0434
# Epoch 91 Batch 100 Loss 0.0273
# Epoch 91 Batch 200 Loss 0.0482
# Epoch 91 Batch 300 Loss 0.0537
# Epoch 91 Batch 400 Loss 0.0441
# Epoch 91 Batch 500 Loss 0.0392
# Epoch 91 Batch 600 Loss 0.0337
# Epoch 91 Batch 700 Loss 0.0541
# Epoch 91 Batch 800 Loss 0.0396
# Epoch 91 Batch 900 Loss 0.0338
# Epoch 91 Batch 1000 Loss 0.0659
# Epoch 91 Batch 1100 Loss 0.0547
# Epoch 91 Batch 1200 Loss 0.0472
# Epoch 91 Batch 1300 Loss 0.0462
# Epoch 91 Batch 1400 Loss 0.0647
# Epoch 91 Batch 1500 Loss 0.0577
# Epoch 91 Batch 1600 Loss 0.0671
# Epoch 91 Batch 1700 Loss 0.0579
# Epoch 91 Batch 1800 Loss 0.0865
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 91 Loss 0.0509
# Validation Accuracy 1.2100
# Time taken for 1 epoch 422.8621463775635 sec
#
# Epoch 92 Batch 0 Loss 0.0389
# Epoch 92 Batch 100 Loss 0.0404
# Epoch 92 Batch 200 Loss 0.0393
# Epoch 92 Batch 300 Loss 0.0433
# Epoch 92 Batch 400 Loss 0.0409
# Epoch 92 Batch 500 Loss 0.0334
# Epoch 92 Batch 600 Loss 0.0581
# Epoch 92 Batch 700 Loss 0.0456
# Epoch 92 Batch 800 Loss 0.0425
# Epoch 92 Batch 900 Loss 0.0449
# Epoch 92 Batch 1000 Loss 0.0495
# Epoch 92 Batch 1100 Loss 0.0507
# Epoch 92 Batch 1200 Loss 0.0449
# Epoch 92 Batch 1300 Loss 0.0716
# Epoch 92 Batch 1400 Loss 0.0583
# Epoch 92 Batch 1500 Loss 0.0847
# Epoch 92 Batch 1600 Loss 0.0924
# Epoch 92 Batch 1700 Loss 0.0579
# Epoch 92 Batch 1800 Loss 0.0837
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 92 Loss 0.0505
# Validation Accuracy 1.1900
# Time taken for 1 epoch 422.6836316585541 sec
#
# Epoch 93 Batch 0 Loss 0.0357
# Epoch 93 Batch 100 Loss 0.0329
# Epoch 93 Batch 200 Loss 0.0340
# Epoch 93 Batch 300 Loss 0.0480
# Epoch 93 Batch 400 Loss 0.0392
# Epoch 93 Batch 500 Loss 0.0399
# Epoch 93 Batch 600 Loss 0.0504
# Epoch 93 Batch 700 Loss 0.0473
# Epoch 93 Batch 800 Loss 0.0532
# Epoch 93 Batch 900 Loss 0.0505
# Epoch 93 Batch 1000 Loss 0.0370
# Epoch 93 Batch 1100 Loss 0.0618
# Epoch 93 Batch 1200 Loss 0.0387
# Epoch 93 Batch 1300 Loss 0.0489
# Epoch 93 Batch 1400 Loss 0.0439
# Epoch 93 Batch 1500 Loss 0.0567
# Epoch 93 Batch 1600 Loss 0.0491
# Epoch 93 Batch 1700 Loss 0.0501
# Epoch 93 Batch 1800 Loss 0.0514
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 93 Loss 0.0507
# Validation Accuracy 1.2000
# Time taken for 1 epoch 418.9204864501953 sec
#
# Epoch 94 Batch 0 Loss 0.0444
# Epoch 94 Batch 100 Loss 0.0469
# Epoch 94 Batch 200 Loss 0.0463
# Epoch 94 Batch 300 Loss 0.0436
# Epoch 94 Batch 400 Loss 0.0219
# Epoch 94 Batch 500 Loss 0.0492
# Epoch 94 Batch 600 Loss 0.0356
# Epoch 94 Batch 700 Loss 0.0581
# Epoch 94 Batch 800 Loss 0.0227
# Epoch 94 Batch 900 Loss 0.0479
# Epoch 94 Batch 1000 Loss 0.0644
# Epoch 94 Batch 1100 Loss 0.0682
# Epoch 94 Batch 1200 Loss 0.0568
# Epoch 94 Batch 1300 Loss 0.0634
# Epoch 94 Batch 1400 Loss 0.0451
# Epoch 94 Batch 1500 Loss 0.0504
# Epoch 94 Batch 1600 Loss 0.0597
# Epoch 94 Batch 1700 Loss 0.0571
# Epoch 94 Batch 1800 Loss 0.0682
# validating 0/100
# validating 10/100
# validating 20/100
# validating 30/100
# validating 40/100
# validating 50/100
# validating 60/100
# validating 70/100
# validating 80/100
# validating 90/100
# Epoch 94 Loss 0.0502
# Validation Accuracy 1.1400
# Time taken for 1 epoch 433.47198009490967 sec
#
# Epoch 95 Batch 0 Loss 0.0562
# Epoch 95 Batch 100 Loss 0.0375
# Epoch 95 Batch 200 Loss 0.0424
# Epoch 95 Batch 300 Loss 0.0354
# Epoch 95 Batch 400 Loss 0.0490
# Epoch 95 Batch 500 Loss 0.0458
# Epoch 95 Batch 600 Loss 0.0540
# Epoch 95 Batch 700 Loss 0.0548
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-665e43456935> in <module>
#       9   for (batch, (alpha, kana)) in enumerate(dataset.take(steps_per_epoch)):
#      10
# ---> 11     batch_loss = train_step(kana, alpha, enc_hidden)
#      12     total_loss += batch_loss
#      13
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
